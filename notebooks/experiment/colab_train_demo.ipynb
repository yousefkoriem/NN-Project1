# %%
import os
import keras
from keras import layers, models, datasets
import pickle
import joblib
import pandas as pd

# %%
# !git clone https://github.com/yousefkoriem/NN-Project1.git
# Out:
# Cloning into 'NN-Project1'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70 (from 1)
# Receiving objects: 100% (70/70), 108.41 MiB | 32.66 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/NN-Project1')

# %%
(x_train,y_train) = pickle.load(open('data/processed/imdb_train.pkl', 'rb'))
(x_test,y_test) = pickle.load(open('data/processed/imdb_test.pkl', 'rb'))

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((25000, 500), (25000, 1), (25000, 500), (25000, 1))

# %%
model = models.load_model('models/architecture/untrained_demo_model.keras')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 20 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
erlystp = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(x_train, y_train, epochs=64, batch_size=32, validation_split=0.2, callbacks=[erlystp])
# Out:
# Epoch 1/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9599 - f1_score: 0.6681 - loss: 0.1110 - precision: 0.9599 - recall: 0.9602 - val_accuracy: 0.8578 - val_f1_score: 0.6626 - val_loss: 0.3959 - val_precision: 0.9410 - val_recall: 0.7605
# Epoch 2/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9767 - f1_score: 0.6702 - loss: 0.0638 - precision: 0.9769 - recall: 0.9766 - val_accuracy: 0.8702 - val_f1_score: 0.6639 - val_loss: 0.4524 - val_precision: 0.8261 - val_recall: 0.9346
# Epoch 3/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9854 - f1_score: 0.6784 - loss: 0.0413 - precision: 0.9851 - recall: 0.9857 - val_accuracy: 0.8830 - val_f1_score: 0.6698 - val_loss: 0.4190 - val_precision: 0.8883 - val_recall: 0.8736
# Epoch 4/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9899 - f1_score: 0.6879 - loss: 0.0286 - precision: 0.9904 - recall: 0.9894 - val_accuracy: 0.8788 - val_f1_score: 0.6781 - val_loss: 0.6016 - val_precision: 0.8422 - val_recall: 0.9293
# Epoch 5/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9916 - f1_score: 0.7069 - loss: 0.0248 - precision: 0.9909 - recall: 0.9924 - val_accuracy: 0.8902 - val_f1_score: 0.7024 - val_loss: 0.5724 - val_precision: 0.8716 - val_recall: 0.9128

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8326 - f1_score: 0.6669 - loss: 0.4743 - precision: 0.9303 - recall: 0.7192

# %%
history_df = pd.DataFrame(history.history)
score_df = pd.DataFrame(score, index=['loss', 'accuracy','f1_score', 'precision', 'recall']).T

# %%
model.save('models/architecture/trained_demo_model.keras')

# %%
joblib.dump(score_df, 'models/evaluation/score.h5')
joblib.dump(history_df, 'models/evaluation/history.h5')
# Out:
# ['models/evaluation/history.h5']

# %%
# !git add -A && (git commit -m "Update from Colab" || echo "No changes to commit") && git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
