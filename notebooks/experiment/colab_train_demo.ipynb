# %%
import os
import keras
from keras import layers, models, datasets
import pickle
import joblib
import pandas as pd

# %%
# !git clone https://github.com/yousefkoriem/NN-Project1.git
# Out:
# Cloning into 'NN-Project1'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 123 (delta 16), reused 46 (delta 9), pack-reused 70 (from 1)
# Receiving objects: 100% (123/123), 108.55 MiB | 23.61 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/NN-Project1')

# %%
(x_train,y_train) = pickle.load(open('data/processed/imdb_train.pkl', 'rb'))
(x_test,y_test) = pickle.load(open('data/processed/imdb_test.pkl', 'rb'))

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((25000, 500), (25000, 1), (25000, 500), (25000, 1))

# %%
model = models.load_model('models/architecture/untrained_demo_model.keras')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 20 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
erlystp = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(x_train, y_train, epochs=64, batch_size=32, validation_split=0.2, callbacks=[erlystp])
# Out:
# Epoch 1/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.7009 - f1_score: 0.6677 - loss: 0.5280 - precision: 0.7053 - recall: 0.6925 - val_accuracy: 0.8666 - val_f1_score: 0.6624 - val_loss: 0.3116 - val_precision: 0.8560 - val_recall: 0.8784
# Epoch 2/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.8927 - f1_score: 0.6677 - loss: 0.2699 - precision: 0.8906 - recall: 0.8958 - val_accuracy: 0.8934 - val_f1_score: 0.6624 - val_loss: 0.2676 - val_precision: 0.8764 - val_recall: 0.9136
# Epoch 3/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9437 - f1_score: 0.6677 - loss: 0.1556 - precision: 0.9455 - recall: 0.9419 - val_accuracy: 0.8906 - val_f1_score: 0.6624 - val_loss: 0.2960 - val_precision: 0.8649 - val_recall: 0.9233
# Epoch 4/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9670 - f1_score: 0.6680 - loss: 0.0904 - precision: 0.9680 - recall: 0.9661 - val_accuracy: 0.8772 - val_f1_score: 0.6625 - val_loss: 0.3737 - val_precision: 0.8361 - val_recall: 0.9354
# Epoch 5/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9794 - f1_score: 0.6702 - loss: 0.0595 - precision: 0.9802 - recall: 0.9788 - val_accuracy: 0.8848 - val_f1_score: 0.6644 - val_loss: 0.4069 - val_precision: 0.8668 - val_recall: 0.9067
# Epoch 6/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9877 - f1_score: 0.6789 - loss: 0.0366 - precision: 0.9882 - recall: 0.9872 - val_accuracy: 0.8670 - val_f1_score: 0.6647 - val_loss: 0.5407 - val_precision: 0.8150 - val_recall: 0.9463
# Epoch 7/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.9894 - f1_score: 0.6890 - loss: 0.0300 - precision: 0.9895 - recall: 0.9894 - val_accuracy: 0.8688 - val_f1_score: 0.6698 - val_loss: 0.5886 - val_precision: 0.8225 - val_recall: 0.9374

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8780 - f1_score: 0.6667 - loss: 0.2902 - precision: 0.8708 - recall: 0.8878

# %%
history_df = pd.DataFrame(history.history)
score_df = pd.DataFrame(score, index=['loss', 'accuracy','f1_score', 'precision', 'recall']).T

# %%
model.save('models/architecture/trained_demo_model.keras')

# %%
joblib.dump(score_df, 'models/evaluation/score.h5')
joblib.dump(history_df, 'models/history/history.h5')
# Out:
# ['models/history/history.h5']
