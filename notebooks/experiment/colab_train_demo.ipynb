# %%
import os
import keras
from keras import layers, models, datasets
import pickle
import joblib
import pandas as pd

# %%
# !git clone https://github.com/yousefkoriem/NN-Project1.git
# Out:
# Cloning into 'NN-Project1'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 98 (delta 9), reused 23 (delta 5), pack-reused 70 (from 1)
# Receiving objects: 100% (98/98), 108.42 MiB | 37.37 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/NN-Project1')

# %%
(x_train,y_train) = pickle.load(open('data/processed/imdb_train.pkl', 'rb'))
(x_test,y_test) = pickle.load(open('data/processed/imdb_test.pkl', 'rb'))

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((25000, 500), (25000, 1), (25000, 500), (25000, 1))

# %%
model = models.load_model('models/architecture/untrained_demo_model.keras')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 20 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
erlystp = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(x_train, y_train, epochs=64, batch_size=32, validation_split=0.2, callbacks=[erlystp])
# Out:
# Epoch 1/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.7145 - f1_score: 0.6677 - loss: 0.5149 - precision: 0.7126 - recall: 0.7211 - val_accuracy: 0.8546 - val_f1_score: 0.6624 - val_loss: 0.3259 - val_precision: 0.8089 - val_recall: 0.9249
# Epoch 2/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.8961 - f1_score: 0.6677 - loss: 0.2604 - precision: 0.8942 - recall: 0.8992 - val_accuracy: 0.8930 - val_f1_score: 0.6624 - val_loss: 0.2668 - val_precision: 0.8918 - val_recall: 0.8922
# Epoch 3/64
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9453 - f1_score: 0.6678 - loss: 0.1505 - precision: 0.9453 - recall: 0.9456 - val_accuracy: 0.8922 - val_f1_score: 0.6624 - val_loss: 0.2801 - val_precision: 0.8715 - val_recall: 0.9176
# Epoch 4/64
# ...

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8806 - f1_score: 0.6667 - loss: 0.2867 - precision: 0.8863 - recall: 0.8731

# %%
history_df = pd.DataFrame(history.history)
score_df = pd.DataFrame(score, index=['loss', 'accuracy','f1_score', 'precision', 'recall']).T

# %%
model.save('models/architecture/trained_demo_model.keras')

# %%
joblib.dump(score_df, 'models/evaluation/score.h5')
joblib.dump(history_df, 'models/history/history.h5')
# Out:
# ['models/history/history2.h5']

# %%
# !git remote add origin https://github.com/yousefkoriem/NN-Project1.git                                                                                         ─╯
# !git branch -M main

# %%
# !git push -u origin main
