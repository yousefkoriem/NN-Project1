# %%
import os
import keras
from keras import layers, models, datasets
import pickle

# %%
os.getcwd()
# Out:
# '/home/bluefox/NN/Project1'

# %%
os.chdir('/home/bluefox/NN/Project1')

# %%
(x_train,y_train) = pickle.load(open('data/processed/imdb_train.pkl', 'rb'))
(x_test,y_test) = pickle.load(open('data/processed/imdb_test.pkl', 'rb'))

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((25000, 500), (25000,), (25000, 500), (25000,))

# %%
model = models.load_model('models/architecture/untrained_demo_model.keras')

# %%
erlystp = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
model.fit(x_train, y_train, epochs=64, batch_size=64, validation_split=0.2, callbacks=[erlystp])
# Out:
# Epoch 1/64
# 2026-05-08 17:44:20.664620: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: INVALID_ARGUMENT: indices[23,412] = 36177 is not in [0, 20000)
# 	 [[{{function_node __inference_one_step_on_data_3845}}{{node functional_1_1/embedding_1/GatherV2}}]]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.fit(x_train, y_train, epochs=64, batch_size=64, validation_split=0.2, callbacks=[erlystp])
#
# File ~/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/NN/Project1/.venv/lib/python3.13/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node functional_1_1/embedding_1/GatherV2 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/traitlets/config/application.py", line 1082, in launch_instance
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/kernelapp.py", line 758, in start
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/bluefox/miniconda3/lib/python3.13/asyncio/base_events.py", line 683, in run_forever
#
#   File "/home/bluefox/miniconda3/lib/python3.13/asyncio/base_events.py", line 2050, in _run_once
#
#   File "/home/bluefox/miniconda3/lib/python3.13/asyncio/events.py", line 89, in _run
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3170, in run_cell
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3225, in _run_cell
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3447, in run_cell_async
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#
#   File "/tmp/ipykernel_5929/22108714.py", line 1, in <module>
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py", line 399, in fit
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py", line 241, in function
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py", line 154, in multi_step_on_iterator
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py", line 134, in one_step_on_data
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/trainer.py", line 59, in train_step
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/layers/layer.py", line 998, in __call__
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/models/functional.py", line 183, in call
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/ops/function.py", line 210, in _run_through_graph
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/models/functional.py", line 695, in call
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/layers/layer.py", line 998, in __call__
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/layers/core/embedding.py", line 169, in call
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/ops/numpy.py", line 7613, in take
#
#   File "/home/bluefox/NN/Project1/.venv/lib/python3.13/site-packages/keras/src/backend/tensorflow/numpy.py", line 3015, in take
#
# indices[23,412] = 36177 is not in [0, 20000)
# 	 [[{{node functional_1_1/embedding_1/GatherV2}}]] [Op:__inference_multi_step_on_iterator_3920]
