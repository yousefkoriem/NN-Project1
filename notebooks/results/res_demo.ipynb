# %%
import os
import keras
from keras import layers, models, datasets
import pickle
import joblib
import pandas as pd
# Out:
# 2026-05-08 23:12:42.241193: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-08 23:12:42.285175: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-08 23:12:43.111753: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-08 23:12:48.065175: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-08 23:12:48.076975: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('/home/bluefox/NN/NN-Project1')

# %%
history = joblib.load('models/history/history.h5','r')
history.head()
# Out:
#    accuracy  f1_score      loss  precision    recall  val_accuracy  \
# 0   0.71445  0.667732  0.514920   0.712610  0.721069        0.8546
# 1   0.89615  0.667732  0.260371   0.894157  0.899242        0.8930
# 2   0.94535  0.667755  0.150457   0.945348  0.945630        0.8922
# 3   0.96805  0.668200  0.088116   0.967427  0.968875        0.8874
# 4   0.98205  0.672639  0.051343   0.981661  0.982542        0.8916
#
#    val_f1_score  val_loss  val_precision  val_recall
# 0      0.662386  0.325877       0.808901    0.924879
# 1      0.662386  0.266763       0.891805    0.892165
# 2      0.662386  0.280079       0.871500    0.917609
# 3      0.662386  0.355374       0.852822    0.933764
# 4      0.663540  0.366716       0.893409    0.886914

# %%
score = joblib.load('models/evaluation/score.h5','r')
score.head()
# Out:
#        loss  accuracy  f1_score  precision   recall
# 0  0.286745   0.88056  0.666667   0.886308  0.87312

# %%
fig, ax = plt.subplots(3,2, figsize=(12,16))

ax[0,0].plot(history['accuracy'])
ax[0,0].plot(history['val_accuracy'],linestyle='--')
ax[0,0].set_title('Accuracy Curve')
ax[0,0].legend(['train','validation'])

ax[0,1].plot(history['loss'])
ax[0,1].plot(history['val_loss'], linestyle='--')
ax[0,1].set_title('Loss Curve')
ax[0,1].legend(['train','validation'])

ax[1,0].plot(history['precision'])
ax[1,0].plot(history['val_precision'], linestyle='--')
ax[1,0].set_title('Precision Curve')
ax[1,0].legend(['train','validation'])

ax[1,1].plot(history['recall'])
ax[1,1].plot(history['val_recall'], linestyle='--')
ax[1,1].set_title('Recall Curve')
ax[1,1].legend(['train','validation'])

ax[2,0].plot(history['f1_score'])
ax[2,0].plot(history['val_f1_score'], linestyle='--')
ax[2,0].set_title('F1-Score Curve')
ax[2,0].legend(['train','validation'])



plt.tight_layout()
plt.show()
